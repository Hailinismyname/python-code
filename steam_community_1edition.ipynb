# %%
from urllib.request import urlopen  
from urllib.parse import urlparse  
from bs4 import BeautifulSoup   
from urllib  import request  
import urllib  
import re
import datetime as dt
import pandas as pd
import csv

data_retrieve=[]

def load_page(url):

    page = request.Request(url)
    #proxy_support=urllib.request.ProxyHandler({'https':'116.232.178.154'})
    opener=urllib.request.build_opener(urllib.request.HTTPHandler)
    urllib.request.install_opener(opener)
    page.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; \
        WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.116 Safari/537.36')

    html = request.urlopen(page).read()


    soup = BeautifulSoup(html,'html.parser')
    print(soup)
    parsing(soup)

def tieba_spider(Url,startPage,endPage):
    for i in range(startPage,endPage+1):
        url= Url+ str(i*50)
        load_page(url)
        print(url)
    print("--------%d----------" %i)

def parsing(html):
    tags_div=html.find_all('div')
    tags_a=html.find_all('id')
    
    global data_retrieve
    
    #for each in tags_a:
        #print(tags_a)
        
        
def replace(x):
    x = re.sub(re.compile('<img.*?>| {7}|'), "", x) #?????7???
    x = re.sub(re.compile('<a.*?>|</a>'), "", x)  #????
    x = re.sub(re.compile('<tr>|<div>|<div></p>'), '\n', x) #??????\n
    x = re.sub(re.compile('<td>'), '\t', x)  #?????\t
    x = re.sub(re.compile('<p.*?>') , "\n  ", x) #?????\n?????
    x = re.sub(re.compile('<br>|<br><br>'), '\n', x) #???????????\n
    x = re.sub(re.compile('<.*?>'), "", x) #??????
    return x.strip()
    
if __name__ == '__main__':
    Url = "https://tieba.baidu.com/f?kw=pubg&ie=utf-8&pn="
    startPage = 0
    endPage=1
    tieba_spider(Url, startPage,endPage)
    
    print("-------------------Complete--------------------")
# Out:
# <!DOCTYPE html>
#
# <!--STATUS OK-->
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="/tb/cms/content-search.xml" rel="search" title="百度贴吧" type="application/opensearchdescription+xml"/>
# <meta content="pubg,客户端网游,游戏,PUBG,大家庭" name="keywords"/>
# <meta content="本吧热帖: 1-求大神  打几局就卡死 2-电脑吃鸡有组队吗？？？在线等 3-卡在这个界面已经接近3天了 试过各种办法 改dns 改ip 4-求大神帮助，已经好多天都进不去了。13号更新后游戏进入黑屏（ 5-找个小圈子 枪刚带脑子的 你要问我怎么算刚单人四排2000分 6-刺激啊刺激 7-这是什么情况啊 8-绝地新项目天启  重金打造  完美兼容  企业级认证！" name="description"/>
# <title>pubg吧-百度贴吧--98K在手、天下我有--欢迎大家加入PUBG大家庭、希望大家好好遵守这个大家庭的规矩，好好爱护这个大家。PUBG是一款休闲射击类游戏，也希望大家能通过PUBG这个大家庭认识更多小伙 </title>
# <script>
# ...
